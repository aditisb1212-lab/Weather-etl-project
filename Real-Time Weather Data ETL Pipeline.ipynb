# %%
import requests
import pandas as pd


API_KEY = "your_api_key"
CITY = "Delhi"
url = f"http://api.openweathermap.org/data/2.5/weather?q={CITY}&appid={API_KEY}&units=metric"

# Step 4: Extract data
response = requests.get(url)
data = response.json()

# Step 5: Print raw data
print("Raw JSON Data:")
print(data)
# Out:
# Raw JSON Data:
# {'coord': {'lon': 77.2167, 'lat': 28.6667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 41.74, 'feels_like': 38.26, 'temp_min': 41.74, 'temp_max': 41.74, 'pressure': 1001, 'humidity': 8, 'sea_level': 1001, 'grnd_level': 976}, 'visibility': 10000, 'wind': {'speed': 3.11, 'deg': 260, 'gust': 4.27}, 'clouds': {'all': 0}, 'dt': 1776943580, 'sys': {'country': 'IN', 'sunrise': 1776903464, 'sunset': 1776950457}, 'timezone': 19800, 'id': 1273294, 'name': 'Delhi', 'cod': 200}

# %%
weather_data = {
    "city": CITY,
    "temperature": data["main"]["temp"],
    "humidity": data["main"]["humidity"],
    "pressure": data["main"]["pressure"],
    "weather": data["weather"][0]["description"]
}

df = pd.DataFrame([weather_data])

print("\nProcessed Data:")
print(df)
# Out:
# Processed Data:
#     city  temperature  humidity  pressure    weather
# 0  Delhi        41.74         8      1001  clear sky

# %%
df.to_csv("weather_data.csv", index=False)
print("\nData saved successfully!")
# Out:
# Data saved successfully!
